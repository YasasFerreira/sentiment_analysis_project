# %%
import numpy as np

# %%
import json
with open("../artifacts/kaggle.json") as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'yasasferreira', 'key': '80e3747734c1c3f8df98102256f67409'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Collecting bleach (from kaggle)
#   Using cached bleach-6.3.0-py3-none-any.whl.metadata (31 kB)
# Collecting certifi>=14.05.14 (from kaggle)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting charset-normalizer (from kaggle)
#   Using cached charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting idna (from kaggle)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\myprojects\sentiment_analysis_project\venv\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting requests (from kaggle)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting setuptools>=21.0.0 (from kaggle)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.10 in d:\myprojects\sentiment_analysis_project\venv\lib\site-packages (from kaggle) (1.17.0)
# Collecting text-unidecode (from kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting urllib3>=1.15.1 (from kaggle)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting webencodings (from kaggle)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: colorama in d:\myprojects\sentiment_analysis_project\venv\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached bleach-6.3.0-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, text-unidecode, urllib3, tqdm, setuptools, python-slugify, protobuf, idna, charset-normalizer, certifi, bleach, requests, kaggle
#
#    --- ------------------------------------  1/13 [text-unidecode]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    --------------- ------------------------  5/13 [python-slugify]
#    --------------- ------------------------  5/13 [python-slugify]
#    --------------- ------------------------  5/13 [python-slugify]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    --------------------- ------------------  7/13 [idna]
#    --------------------- ------------------  7/13 [idna]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    --------------------------- ------------  9/13 [certifi]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ---------------------------------------- 13/13 [kaggle]
#
# Successfully installed bleach-6.3.0 certifi-2025.10.5 charset-normalizer-3.4.4 idna-3.11 kaggle-1.7.4.5 protobuf-6.33.0 python-slugify-8.0.4 requests-2.32.5 setuptools-80.9.0 text-unidecode-1.3 tqdm-4.67.1 urllib3-2.5.0 webencodings-0.5.1

# %%
import os
os.environ['KAGGLE_USERNAME'] = data ['username']
os.environ['KAGGLE_KEY'] = data ['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path="../artifacts/")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile("../artifacts/sentiment-analysis-dataset.zip",'r') as zip_ref:
    zip_ref.extractall("../artifacts/")
